# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row, column
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, CustomJS, FixedTicker
import bokeh.palettes as pal
from bokeh.layouts import layout, Spacer, gridplot
output_notebook()

import ipywidgets as widgets
from ipywidgets import *
from IPython.display import display, clear_output

from bokeh.charts import Bar, Histogram

import numpy as np
from numpy import *

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

eps=1e-08
N=15
dims=[100,100]

gx=(dims[0]+1)/2
gy=(dims[1]+1)/2

delta=3
sigma2=delta*delta/4 # sigma=delta/2

a = np.arange(100.0) 
b = np.arange(100.0)

mu_x = gx
mu_y = gy

Fx = np.reshape(exp(-square((a - mu_x) / (2*sigma2))),[1,dims[0]])
Fy = np.reshape(exp(-square((b - mu_y) / (2*sigma2))),[1,dims[1]])
# nomalize
Fx=Fx/max(sum(Fx),eps)
Fy=Fy/max(sum(Fy),eps)

img = ones([dims[0],dims[1]])
# blob
img[40,40]=255

Fxt = np.transpose(Fx)


Fy*img*Fxt

b = Button(description="Loading...", icon="arrow", width=400)

figures = list()
iqs = list()
charts = list()
curves = list()

def on_click(b, new_image=True):
    b.description = "Loading..."
    #update_figures(handle, new_image=new_image)
    b.description = "Next (Random) Image"

on_click(b)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a5bdda6d-f2c0-4e94-9f9b-03a06e0b9aaa">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.models import ColumnDataSource, CustomJS, HoverTool

# %%
from bokeh.plotting import figure, output_file, show

plot = figure(plot_width=300, plot_height=300)
source = ColumnDataSource(data=dict(top=[2, 3, 4], bottom=[1, 2, 3], left=[1, 2, 3], right=[1.2, 2.5, 3.7]))
plot.quad('left', 'right', 'top', 'bottom',source=source, color="#B3DE69")
show(plot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-de02ca969457> in <module>()
#       4 source = ColumnDataSource(data=dict(top=[2, 3, 4], bottom=[1, 2, 3], left=[1, 2, 3], right=[1.2, 2.5, 3.7]))
#       5 plot.quad('left', 'right', 'top', 'bottom',source=source, color="#B3DE69")
# ----> 6 show(plot)
#
# ~/.local/lib/python3.5/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     285
#     286     if obj not in _state.document.roots:
# --> 287         _state.document.add_root(obj)
#     288     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     289
#
# ~/.local/lib/python3.5/site-packages/bokeh/document.py in add_root(self, model, setter)
#     278             self._roots.append(model)
#     279         finally:
# --> 280             self._pop_all_models_freeze()
# ...

# %%
from Retina_Viz import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-8db834d2c263> in <module>()
# ----> 1 from Retina_Viz import *
#
# ~/DRAM/Retina_Viz.py in <module>()
#     232 dropdown.observe(on_change)
#     233 display(HBox([b, dropdown]))
# --> 234 handle = show(layout(figures), notebook_handle=True)
#     235 # update_figures(handle)
#     236 on_click(b)
#
# ~/.local/lib/python3.5/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     285
#     286     if obj not in _state.document.roots:
# --> 287         _state.document.add_root(obj)
#     288     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     289
#
# ~/.local/lib/python3.5/site-packages/bokeh/document.py in add_root(self, model, setter)
#     278             self._roots.append(model)
#     279         finally:
# ...

# %%
# Out:
# array([[ -4.95934048e+01,  -4.25086327e+01,  -3.54238606e+01,
#          -2.83390884e+01,  -2.12543163e+01,  -1.41695442e+01,
#          -7.08477211e+00,   0.00000000e+00,   7.08477211e+00,
#           1.41695442e+01,   2.12543163e+01,   2.83390884e+01,
#           3.54238606e+01,   4.25086327e+01,   4.95934048e+01],
#        [ -4.95934048e+01,  -3.23139650e+01,  -2.69283042e+01,
#          -2.15426434e+01,  -1.61569825e+01,  -1.07713217e+01,
#          -5.38566084e+00,   0.00000000e+00,   5.38566084e+00,
#           1.07713217e+01,   1.61569825e+01,   2.15426434e+01,
#           2.69283042e+01,   3.23139650e+01,   4.95934048e+01],
#        [ -4.95934048e+01,  -3.23139650e+01,  -2.17761206e+01,
#          -1.74208965e+01,  -1.30656724e+01,  -8.71044824e+00,
#          -4.35522412e+00,   3.55271368e-15,   4.35522412e+00,
#           8.71044824e+00,   1.30656724e+01,   1.74208965e+01,
#           2.17761206e+01,   3.23139650e+01,   4.95934048e+01],
# ...
