# %% [markdown]
# # DRAM Visualizer

# %%
from viz_filterbank import *
# Out:
# Setting everything up!
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="335ddf3f-b466-4639-83ab-a0dbe4490a54">Loading BokehJS ...</span>
#     </div>
# /home/sychen23/.local/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
# ['/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py', 'true', 'true', 'true', 'true', 'true', 'true', 'model_runs/rewrite_filterbank/classify_log.csv', 'model_runs/rewrite_filterbank/classifymodel_0.ckpt', 'model_runs/rewrite_filterbank/classifymodel_', 'model_runs/rewrite_filterbank/zzzdraw_data_5000.npy', 'false', 'true', 'false', 'false', 'true']
# ...
