# %% [markdown]
# # DRAM Filterbank Visualizer

# %% [markdown]
# To visualize the move attention DRAM model, DRAM_move_attn, use these settings:
# min_edge = 7,
# max_edge = 7,
# min_blobs = 1,
# max_blobs = 5,
# batch_size = 1.
# Change analysis.py to import DRAM_move_attn and load the DRAM_sensical checkpoint.

# %%
from viz_filterbank import *
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9dfb01b1-4784-41f1-b356-57b8f6d9341b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9dfb01b1-4784-41f1-b356-57b8f6d9341b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("359e6dbc-f61f-4fed-b2f4-11b21ab5a8a1", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9dfb01b1-4784-41f1-b356-57b8f6d9341b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9dfb01b1-4784-41f1-b356-57b8f6d9341b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a976bacc-a95d-4047-b940-98c1ac7235b6":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"mu_x_list"},"y":{"field":"mu_y_list"}},"id":"6e62f64b-9649-4bbc-bd19-898c658e74ca","type":"Circle"},{"attributes":{"code":"\n    console.log(cb_data);\n    if (IPython.notebook.kernel !== undefined) {\n        var kernel = IPython.notebook.kernel;\n        var i = 5;\n        if (!this.hovered) {\n            cmd = \"hover(\" + i + \")\";\n            kernel.execute(cmd, {}, {});\n            this.hovered = true;\n        }\n        \n        var that = this;\n        \n        \n        document.querySelectorAll(\".bk-plot-layout.bk-layout-fixed\").forEach(function(x) {\n            x.onmouseleave = function() {\n                if (!that.hovered) {\n                    return;\n                }\n                that.hovered = false;\n                cmd = \"unhover(\" + i + \")\";\n                kernel.execute(cmd, {}, {});\n            }\n        })\n        \n    }\n    "},"id":"3ad510be-3bef-4cd3-88a0-c97e754c1eff","type":"CustomJS"},{"attributes":{"callback":null,"end":0,"start":40},"id":"963ab9da-38b8-4019-98ff-2996276aa4e2","type":"Range1d"},{"attributes":{"color_mapper":{"id":"bd9f1f56-e0b3-4c58-a076-1abf1f235019","type":"LinearColorMapper"},"dh":{"units":"data","value":40},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":40}},"id":"da1eab10-3d92-4821-9655-a11c400e3d4c","type":"Image"},{"attributes":{"dimension":1,"plot":{"id":"5d2b6273-aa12-474a-aba4-b27a5532209f","subtype":"Figure","type":"Plot"},"ticker":{"id":"601812c4-189f-4a4b-a705-3e90eecdece5","type":"BasicTicker"}},"id":"868bd825-abfa-4f77-833f-9119f45c1717","type":"Grid"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[40,200]}]}},"id":"3d0f9cd4-316a-477d-b13f-0a75b7cf7240","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"mu_x_list"},"y":{"field":"mu_y_list"}},"id":"f270e882-2fc4-4ecb-81ff-c2d6c2aefdb2","type":"Circle"},{"attributes":{"palette":["#000000","#010101","#020202","#030303","#040404","#050505","#060606","#070707","#080808","#090909","#0a0a0a","#0b0b0b","#0c0c0c","#0d0d0d","#0e0e0e","#0f0f0f","#101010","#111111","#121212","#131313","#141414","#151515","#161616","#171717","#181818","#191919","#1a1a1a","#1b1b1b","#1c1c1c","#1d1d1d","#1e1e1e","#1f1f1f","#202020","#212121","#222222","#232323","#242424","#252525","#262626","#272727","#282828","#292929","#2a2a2a","#2b2b2b","#2c2c2c","#2d2d2d","#2e2e2e","#2f2f2f","#303030","#313131","#323232","#333333","#343434","#353535","#363636","#373737","#383838","#393939","#3a3a3a","#3b3b3b","#3c3c3c","#3d3d3d","#3e3e3e","#3f3f3f","#404040","#414141","#424242","#434343","#444444","#454545","#464646","#474747","#484848","#494949","#4a4a4a","#4b4b4b","#4c4c4c","#4d4d4d","#4e4e4e","#4f4f4f","#505050","#515151","#525252","#535353","#545454","#555555","#565656","#575757","#585858","#595959","#5a5a5a","#5b5b5b","#5c5c5c","#5d5d5d","#5e5e5e","#5f5f5f","#606060","#616161","#626262","#636363","#646464","#656565","#666666","#676767","#686868","#696969","#6a6a6a","#6b6b6b","#6c6c6c","#6d6d6d","#6e6e6e","#6f6f6f","#707070","#717171","#727272","#737373","#747474","#757575","#767676","#777777","#787878","#797979","#7a7a7a","#7b7b7b","#7c7c7c","#7d7d7d","#7e7e7e","#7f7f7f","#808080","#818181","#828282","#838383","#848484","#858585","#868686","#878787","#888888","#898989","#8a8a8a","#8b8b8b","#8c8c8c","#8d8d8d","#8e8e8e","#8f8f8f","#909090","#919191","#929292","#939393","#949494","#959595","#969696","#979797","#989898","#999999","#9a9a9a","#9b9b9b","#9c9c9c","#9d9d9d","#9e9e9e","#9f9f9f ...
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_364000.ckpt
# prediction (x, y):  [ 44.3061142] ,  [ 19.98993874]
# prediction (x, y):  [ 64.0251236] ,  [ 23.26644135]
# prediction (x, y):  [ 82.80699921] ,  [ 17.29125214]
# prediction (x, y):  [ 101.55674744] ,  [ 21.00938797]
# prediction (x, y):  [ 106.07307434] ,  [ 24.15956116]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_364000.ckpt
# gx:  [[ 31.]] , gy:  [[ 23.]]
# gx:  [[ 49.]] , gy:  [[ 22.]]
# gx:  [[ 68.]] , gy:  [[ 20.]]
# gx:  [[ 86.]] , gy:  [[ 16.]]
# gx:  [[ 104.]] , gy:  [[ 24.]]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_364000.ckpt
# prediction (x, y):  [ 44.3061142] ,  [ 19.98993874]
# prediction (x, y):  [ 64.0251236] ,  [ 23.26643562]
# prediction (x, y):  [ 82.80699921] ,  [ 17.29122925]
# prediction (x, y):  [ 101.5567627] ,  [ 21.00937462]
# prediction (x, y):  [ 106.07309723] ,  [ 24.1595726]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_365000.ckpt
# prediction (x, y):  [ 44.97764206] ,  [ 16.74858284]
# prediction (x, y):  [ 64.3530426] ,  [ 22.15627098]
# prediction (x, y):  [ 81.31755066] ,  [ 18.61294556]
# prediction (x, y):  [ 102.68953705] ,  [ 23.45215225]
# prediction (x, y):  [ 107.6474762] ,  [ 25.10698128]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_365000.ckpt
# prediction (x, y):  [ 45.7914238] ,  [ 19.50745392]
# prediction (x, y):  [ 61.82942963] ,  [ 21.92797661]
# prediction (x, y):  [ 72.09581757] ,  [ 22.56024361]
# prediction (x, y):  [ 94.75208282] ,  [ 24.42355156]
# prediction (x, y):  [ 80.26532745] ,  [ 23.39101028]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_365000.ckpt
# prediction (x, y):  [ 48.13033676] ,  [ 20.04742241]
# prediction (x, y):  [ 62.98704147] ,  [ 12.87381458]
# prediction (x, y):  [ 74.73589325] ,  [ 16.75613022]
# prediction (x, y):  [ 89.45387268] ,  [ 19.03380966]
# prediction (x, y):  [ 91.84015656] ,  [ 17.64104843]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_365000.ckpt
# gx:  [[ 32.]] , gy:  [[ 14.]]
# gx:  [[ 47.]] , gy:  [[ 20.]]
# gx:  [[ 63.]] , gy:  [[ 14.]]
# gx:  [[ 74.]] , gy:  [[ 18.]]
# gx:  [[ 91.]] , gy:  [[ 18.]]
# INFO:tensorflow:Restoring parameters from model_runs/sensical/classifymodel_365000.ckpt
# prediction (x, y):  [ 48.13032913] ,  [ 20.04742813]
# prediction (x, y):  [ 62.98701859] ,  [ 12.87383842]
# prediction (x, y):  [ 74.73592377] ,  [ 16.75614166]
# prediction (x, y):  [ 89.45385742] ,  [ 19.03379631]
# prediction (x, y):  [ 91.84011841] ,  [ 17.64103699]
