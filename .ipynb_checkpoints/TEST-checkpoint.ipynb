# %%
import numpy as np
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import operator
from analysis_count_0g import read_n, classify_imgs2
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py', '-f', 'true', 'true', 'true', 'true', 'true', 'model_runs/-f/count_log.csv', 'model_runs/-f/countmodel_0.ckpt', 'model_runs/-f/countmodel_', 'true', 'false', 'false', 'true']
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# analysis_count.py

# %%
model_name = "3task_0305"
num_runs = 1
test_trials = 10
iter_list = [151750]#np.arange(0,3500,500)#[3200, 4800, 6400, 9600, 12800]#, 200, 300, 400, 600, 800, 1200]#, 1600, 2400, 3200, 4800, 6400, 9600, 12800, 19200, 25600, 38400, 51200, 76800, 102400]#, 153600, 204800, 307200, 409600, 614400, 819200, 1000000]
            #[0, 400, 800, 1600, 3200, 6400, 12800, 25600]#, 51200, 76800, 102400]#, 153600, 204800, 307200, 409600, 614400, 819200, 1000000, 2000000, 3000000, 4000000]
             #[0, 1000, 4000, 16000, 32000, 64000, 125000, 250000, 500000, 600000]
#iter_list = np.arange(0,11100000,100000)
glimpse_list = np.arange(0,10,1)
max_blobs = 9
min_blobs = 1

num_iters = len(iter_list)
num_glimpses = len(glimpse_list)
blob_list = np.arange(0,10,1)
output_size = max_blobs - min_blobs + 2 # 10
data_directory = "data/" + model_name + "/"
m = 0.5
num_imgs = test_trials*(output_size-1)

blob_point_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
class_all_runs = np.zeros([num_runs, num_iters, num_imgs])
pred_gx_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
tchr_gx_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
pred_gy_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
tchr_gy_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
size_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])

# %%
def fill_matrix(path, iteration):
    """Fill the confidence and choice matrices for one run at one iteration."""
    
    data = None
    num_imgs = test_trials*(output_size-1) # batch_size
    imgs_data = classify_imgs2(iteration, True, num_imgs, path=path) # new_imgs = True
        
    blob_point_one_run = np.zeros([num_imgs, output_size+1])
    class_one_run = np.zeros(num_imgs)
    pred_gx_one_run = np.zeros([num_imgs, output_size+1])
    tchr_gx_one_run = np.zeros([num_imgs, output_size+1])
    pred_gy_one_run = np.zeros([num_imgs, output_size+1])
    tchr_gy_one_run = np.zeros([num_imgs, output_size+1])
    size_one_run = np.zeros([num_imgs, output_size+1])
    
    for idx, data in enumerate(imgs_data):
        for g in range(num_glimpses):
            blob_point_one_run[idx][g] = int(data["blob_point"][g])
            pred_gx_one_run[idx][g] = data["xs"][g][0]
            tchr_gx_one_run[idx][g] = data["xs"][g][1]
            pred_gy_one_run[idx][g] = data["ys"][g][0]
            tchr_gy_one_run[idx][g] = data["ys"][g][1]
            size_one_run[idx][g] = int(data["size"][g])
        class_one_run[idx] = data["class"]+1      
    
    return blob_point_one_run, class_one_run, pred_gx_one_run, tchr_gx_one_run, pred_gy_one_run, tchr_gy_one_run, size_one_run

# %%
for run in range(num_runs):
    path = 'model_runs/' + model_name + '_run_' + str(run + 1) 
#     path = 'model_runs/DRAM_test_square'
    for i, iteration in enumerate(iter_list):
        blob_point_all_runs[run, i], class_all_runs[run, i], pred_gx_all_runs[run, i], tchr_gx_all_runs[run, i], pred_gy_all_runs[run, i], tchr_gy_all_runs[run, i], size_all_runs[run, i] = fill_matrix(path, iteration)
# Out:
# INFO:tensorflow:Restoring parameters from model_runs/3task_0305_run_1/countmodel_151750.ckpt

# %%
class_all_runs[0,1,2]
tchr_gx_all_runs[0,0,0][0:10]
#size_all_runs[0,0,0]
blob_point_all_runs[0,1,0]
tchr_gx_all_runs[0,1,0][0:10]
# Out:
# array([  9.,  18.,  27.,  35.,  35.,  35.,  35.,  35.,  35.,  35.])

# %%
tchr_gx_all_runs[0,1,0][0:10]
# Out:
# array([  9.,  18.,  27.,  35.,  35.,  35.,  35.,  35.,  35.,  35.])

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

it=0
for t in range(num_imgs):
    if class_all_runs[0,it,t]==5:
        img=t
        break
        
# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size

# generate blobs
blob_size = int(class_all_runs[0,it,img])*[5]
height = np.zeros(int(class_all_runs[0,it,img]))
#blob_size = [5,5,5,5,5,5,5,5,5]
#height = [0,0,0,0,0,0,0,0,0]

# top left corner coordinate
cX = tchr_gx_all_runs[0,it,img][0:int(class_all_runs[0,it,img])]-2
cY = tchr_gy_all_runs[0,it,img][0:int(class_all_runs[0,it,img])]-2
#cX = [8,17,25,33,42,51,60,68,77]
#cY = [47,48,48,47,48,47,47,48,47]


k = len(cX)
for t in range(k):
    height[t] = blob_size[t]
width = height # square blobs

# input_img
input_img = np.ones(dims[0]*dims[1])
for i in range(k):
    for j in range(int(cY[i]), int(cY[i]+height[i])):
        for k in range(int(cX[i]), int(cX[i]+width[i])):
            input_img[j*dims[0]+k] = 255
            
input_img = np.reshape(input_img,(dims[0],dims[1]))

# %%
tchr_gx_all_runs[0,0,0]

# %%
print("blob_point:", blob_point_all_runs[0,it,img][0:int(class_all_runs[0,it,img]+1)])
for i in range(int(class_all_runs[0,it,img]+1)):
               # attention window
               gx = tchr_gx_all_runs[0,it,img,i]
               gy = tchr_gy_all_runs[0,it,img,i]
               pred_gx = pred_gx_all_runs[0,it,img,i]
               pred_gy = pred_gy_all_runs[0,it,img,i]

               xx=np.reshape([gx+0.5-3.5,gx+0.5,gx+0.5+3.5], (-1,1))
               yy=np.reshape([gy+0.5-3.5,gy+0.5,gy+0.5+3.5], (-1,1))
               mu_x_1_list = np.reshape([xx]*3,[-1])
               mu_y_1_list = np.reshape(np.transpose([yy]*3),[-1])

               input_img = np.reshape(input_img,(dims[0],dims[1]))

               cross_source = ColumnDataSource(
                   data=dict(
                       cross_x=[gx+0.5],
                       cross_y=[gy+0.5],
                       desc=['Att_window Center'],
                   )
               )

               dot_source_1 = ColumnDataSource(
                   data=dict(
                       mu_x_1=mu_x_1_list,
                       mu_y_1=mu_y_1_list,
                   )
               )

               source = ColumnDataSource(
                   data=dict(
                       x=[pred_gx],
                       y=[pred_gy],
                   )
               )

               p = figure(title="Input Image (gx=%-d, gy=%-d)" %(gx,gy), x_range=(0, 100), y_range=(0, 100))
               iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
               p.circle('mu_x_1', 'mu_y_1', size=5, source=dot_source_1, color="orange")
               p.cross('cross_x', 'cross_y', size=10, source=cross_source, color="blue")
               p.circle('x', 'y', size=5, source=source, color="red")

               output_notebook()

               show(p)
# Out:
# blob_point: [ 1.  2.  3.  4.  5.  5.]
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86dd8e6b-cb75-4bfa-b73e-fc57e02be514">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="92829f0c-579d-43e9-9551-35b9d3adb3aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("92829f0c-579d-43e9-9551-35b9d3adb3aa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("92829f0c-579d-43e9-9551-35b9d3adb3aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '92829f0c-579d-43e9-9551-35b9d3adb3aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"754c933a-749a-486b-98a8-593cfe929be4":{"roots":{"references":[{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"field":"cross_x"},"y":{"field":"cross_y"}},"id":"b2074528-8172-4f63-8d41-627980e9269f","type":"Cross"},{"attributes":{"data_source":{"id":"5c89074a-7fb4-4210-8092-bda822d5ea19","type":"ColumnDataSource"},"glyph":{"id":"f12d2210-cf35-4a0c-9965-ec3ae544f65c","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":
type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":100},"id":"abed01e6-250d-4ce2-a083-225f2df7fa4d","type":"Range1d"},{"attributes":{"plot":{"id":"e5e779f9-9b76-48d6-875f-78efbd745256","subtype":"Figure","type":"Plot"}},"id":"a7ed7863-1a92-418d-bcb8-56c6e30ca787","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e5e779f9-9b76-48d6-875f-78efbd745256","subtype":"Figure","type":"Plot"}},"id":"b2dd5d41-49c1-4604-9154-ec5513dd4c14","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e4a151db-9bd8-4d3a-ad0d-812cf47bdba8","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["desc","cross_x","cross_y"],"data":{"cross_x":[44.5],"cross_y":[50.5],"desc":["Att_window Center"]}},"id":"6348f957-8c0e-4a30-b0b5-96ce7ff4c78f","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4f16f9d6-a123-467a-9b59-fed87a52ef4c","type":"PanTool"},{"id":"a7ed7863-1a92-418d-bcb8-56c6e30ca787","type":"WheelZoomTool"},{"id":"1bac25ef-7ca6-445b-8fc9-0281e5d2a1dc","type":"BoxZoomTool"},{"id":"932f1e61-adf9-4e18-8219-87795f765f01","type":"SaveTool"},{"id":"b2dd5d41-49c1-4604-9154-ec5513dd4c14","type":"ResetTool"},{"id":"88563bba-33b5-49f0-9e52-d107703a584c","type":"HelpTool"}]},"id":"1f5b12eb-219e-4520-a31b-56ff08efb4c8","type":"Toolbar"},{"attributes":{"formatter":{"id":"90b13506-a7fb-46c5-863f-9f5f6c149e53","type":"BasicTickFormatter"},"plot":{"id":"e5e779f9-9b76-48d6-875f-78efbd745256","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5481639-2c75-4208-b2d5-23e4aee75ef6","type":"BasicTicker"}},"id":"30198fdf-6d01-4773-8f65-9a6e74ca7a39","type":"LinearAxis"},{"attributes":{"palette":["#000000","#010101","#020202","#030303","#040404","#050505","#060606","#070707","#080808","#090909","#0a0a0a","#0b0b0b","#0c0c0c","#0d0d0d","#0e0e0e","#0f0f0f","#101010","#111111","#121212","#131313","#141414","#151515","#161616","#171717","#181818","#191919","#1a1a1a","#1b1b1b","#1c1c1c","#1d1d1d","#1e1e1e","#1f1f1f","#202020","#212121","#222222","#232323","#242424","#252525","#262626","#272727","#282828","#292929","#2a2a2a","#2b2b2b","#2c2c2c","#2d2d2d","#2e2e2e","#2f2f2f","#303030","#313131","#323232","#333333","#343434","#353535","#363636","#373737","#383838","#393939","#3a3a3a","#3b3b3b","#3c3c3c","#3d3d3d","#3e3e3e","#3f3f3f","#404040","#414141","#424242","#434343","#444444","#454545","#464646","#474747","#484848","#494949","#4a4a4a","#4b4b4b","#4c4c4c","#4d4d4d","#4e4e4e","#4f4f4f","#505050","#515151","#525252","#535353","#545454","#555555","#565656","#575757","#585858","#595959","#5a5a5a","#5b5b5b","#5c5c5c","#5d5d5d","#5e5e5e","#5f5f5f","#606060","#616161","#626262","#636363","#646464","#656565","#666666","#676767","#686868","#696969","#6a6a6a","#6b6b6b","#6c6c6c","#6d6d6d","#6e6e6e","#6f6f6f","#707070","#717171","#727272","#737373","#747474","#757575","#767676","#777777","#787878","#797979","#7a7a7a","#7b7b7b","#7c7c7c","#7d7d7d","#7e7e7e","#7f7f7f","#808080","#818181","#828282","#838383","#848484","#858585","#868686","#878787","#888888","#898989","#8a8a8a","#8b8b8b","#8c8c8c","#8d8d8d","#8e8e8e","#8f8f8f","#909090","#919191","#929292","#939393","#949494","#959595","#969696","#979797","#989898","#999999","#9a9a9a","#9b9b9b","#9c9c9c","#9d9d9d","#9e9e9e","#9f9f9f","#a0a0a0","#a1a1a1","#a2a2a2","#a3a3a3","#a4a4a4","#a5a5a5","#a6a6a6","#a7a7a7","#a8a8a8","#a9a9a9","#aaaaaa","#ababab","#acacac","#adadad","#aeaeae","#afafaf","#b0b0b0","#b1b1b1","#b2b2b2","#b3b3b3","#b4b4b4","#b5b5b5","#b6b6b6","#b7b7b7","#b8b8b8" ...

# %% [markdown]
# # Generate Image

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size
num_blobs = 5
img = np.ones(dims[0]*dims[1])
img_width = dims[0]
img_height = dims[1]
num_count = 0
glimpse_count = 0
# top left corner coordinate
cX_prev = 0
cY_prev = 0
# generate blobs
while num_count < num_blobs:
    width = 5
    height = 5
    cX_ = random.randint(8, 9)
    cY_ = 3
    if num_count == 0:
        cX = cX_
    else:
        cX = cX_prev + cX_
    cY = 53-5#random.randint(img_height/2 - cY_, img_height/2 + cY_ - height)
    cX_prev = cX
    cY_prev = cY
        
    for p in range(cY, cY+height):
        for q in range(cX, cX+width):
            img[p*img_width+q] = 255
                
    num_count += 1
    glimpse_count += 1

# %%
input_img = np.reshape(img,(dims[0],dims[1]))
p = figure(x_range=(-10, 110), y_range=(-10, 110))
iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d0f6a590-249e-4fd9-a9b7-15d2c74648b2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bfd3e9d-f444-480a-9364-934841e0c400"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bfd3e9d-f444-480a-9364-934841e0c400");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bfd3e9d-f444-480a-9364-934841e0c400");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bfd3e9d-f444-480a-9364-934841e0c400' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"456f6804-050e-4222-877a-60f76759745a":{"roots":{"references":[{"attributes":{},"id":"2f53c8be-4d7f-4f68-9ca5-1af1be7f2bb3","type":"LinearScale"},{"attributes":{},"id":"b5378f21-d2d1-4d85-8d45-48bce2510a82","type":"ToolEvents"},{"attributes":{"palette":["#000000","#010101","#020202","#030303","#040404","#050505","#060606","#070707","#080808","#090909","#0a0a0a","#0b0b0b","#0c0c0c","#0d0d0d","#0e0e0e","#0f0f0f","#101010","#111111","#121212","#131313","#141414","#151515","#161616","#171717","#181818","#191919","#1a1a1a","#1b1b1b","#1c1c1c","#1d1d1d","#1e1e1e","#1f1f1f","#202020","#212121","#222222","#232323","#242424","#252525","#262626","#272727","#282828","#292929","#2a2a2a","#2b2b2b","#2c2c2c","#2d2d2d","#2e2e2e","#2f2f2f","#303030","#313131","#323232","#333333","#343434","#353535","#363636","#373737","#383838","#393939","#3a3a3a","#3b3b3b","#3c3c3c","#3d3d3d","#3e3e3e","#3f3f3f","#404040","#414141","#424242","#434343","#444444","#454545","#464646","#474747","#484848","#494949","#4a4a4a","#4b4b4b","#4c4c4c","#4d4d4d","#4e4e4e","#4f4f4f","#505050","#515151","#525252","#535353","#545454","#555555","#565656","#575757","#585858","#595959","#5a5a5a","#5b5b5b","#5c5c5c","#5d5d5d","#5e5e5e","#5f5f5f","#606060","#616161","#626262","#636363","#646464","#656565","#666666","#676767","#686868","#696969","#6a6a6a","#6b6b6b","#6c6c6c","#6d6d6d","#6e6e6e","#6f6f6f","#707070","#717171","#727272","#737373","#747474","#757575","#767676","#777777","#787878","#797979","#7a7a7a","#7b7b7b","#7c7c7c","#7d7d7d","#7e7e7e","#7f7f7f","#808080","#818181","#828282","#838383","#848484","#858585","#868686","#878787","#888888","#898989","#8a8a8a","#8b8b8b","#8c8c8c","#8d8d8d","#8e8e8e","#8f8f8f","#909090","#919191","#929292","#939393","#949494","#959595","#969696","#979797","#989898","#999999","#9a9a9a","#9b9b9b","#9c9c9c","#9d9d9d","#9e9e9e","#9f9f9f","#a0a0a0","#a1a1a1","#a2a2a2","#a3a3a3","#a4a4a4","#a5a5a5","#a6a6a6","#a7a7a7","#a8a8a8","#a9a9a9","#aaaaaa","#ababab","#acacac","#adadad","#aeaeae","#afafaf","#b0b0b0","#b1b1b1","#b2b2b2","#b3b3b3","#b4b4b4","#b5b5b5","#b6b6b6","#b7b7b7","#b8b8b8","#b9b9b9","#bababa","#bbbbbb","#bcbcbc","#bdbdbd","#bebebe","#bfbfbf","#c0c0c0","#c1c1c1","#c2c2c2","#c3c3c3","#c4c4c4","#c5c5c5","#c6c6c6","#c7c7c7","#c8c8c8","#c9c9c9","#cacaca","#cbcbcb","#cccccc","#cdcdcd","#cecece","#cfcfcf","#d0d0d0","#d1d1d1","#d2d2d2","#d3d3d3","#d4d4d4","#d5d5d5","#d6d6d6","#d7d7d7","#d8d8d8","#d9d9d9","#dadada","#dbdbdb","#dcdcdc","#dddddd","#dedede","#dfdfdf","#e0e0e0","#e1e1e1","#e2e2e2","#e3e3e3","#e4e4e4","#e5e5e5","#e6e6e6","#e7e7e7","#e8e8e8","#e9e9e9","#eaeaea","#ebebeb","#ececec","#ededed","#eeeeee","#efefef","#f0f0f0","#f1f1f1","#f2f2f2","#f3f3f3","#f4f4f4","#f5f5f5","#f6f6f6","#f7f7f7","#f8f8f8","#f9f9f9","#fafafa","#fbfbfb","#fcfcfc","#fdfdfd","#fefefe","#ffffff"]},"id":"3a22a5a4-8cf8-450d-b37a-cf2a3c3d1d31","type":"LinearColorMapper"},{"attributes":{"formatter":{"id":"59619735-b504-4561-bb7b-3a175dbc96d5","type":"BasicTickFormatter"},"plot":{"id":"548af634-07de-4ff5-9c43-abf3e03e9c18","subtype":"Figure","type":"Plot"},"ticker":{"id":"212865eb-e764-4bbe-ba06-11ef9c7450a8","type":"BasicTicker"}},"id":"afc7136b-fe62-420f-bdff-3aa8002ed2ac","type":"LinearAxis"},{"attributes":{},"id":"59619735-b504-4561-bb7b-3a175dbc96d5","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"03dc3434-4d2b-4d48-a316-c9f1be8576ba","type":"PanTool"},{"id":"02b776ee-6e00-4345-8453-4cbde0cca8b9","type":"WheelZoomTool"},{"id":"deb5ecf1-1db8-40c9-8bc0-0c712a07bd09","type":"BoxZoomTool"},{"id":"5e4f19ac-a859-4f53-8dc2-5012b1473296","type":"SaveTool"},{"id":"fe5242de-fabc-462b-8198-6f7ec856c22a","type":"ResetTool"},{"id":"cd0a892f-1fed-4426-a877-aa7a86d0accb","type":"HelpTool"}]},"id":"ce62f0d1-57b3-45ee-98e4-9397f9c7cea9","type":"Toolbar"},{"attributes":{"callback":null,"end":110,"start":-10},"id":"2a22a563-205b-4f11-9875-fac8cbf7e815 ...

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size
num_blobs = 5
img = np.ones(dims[0]*dims[1])
img_width = dims[0]
img_height = dims[1]
num_count = 0
glimpse_count = 0
# generate blobs
for p in range(0, 6):
    for q in range(0, 6):
        img[p*img_width+q] = 255
        
input_img = np.reshape(img,(dims[0],dims[1]))
p = figure(x_range=(-10, 110), y_range=(-10, 110))
iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ad69fa7f-34cc-4a04-881f-b17d2b35dfca">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="118d2401-a32a-4999-a017-8cdce7976b20"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("118d2401-a32a-4999-a017-8cdce7976b20");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("118d2401-a32a-4999-a017-8cdce7976b20");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '118d2401-a32a-4999-a017-8cdce7976b20' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6b5fe4be-186d-4972-8d03-5892ad4e32a1":{"roots":{"references":[{"attributes":{},"id":"f40db235-9a6f-46cb-b0ef-250e4e5d5662","type":"LinearScale"},{"attributes":{"data_source":{"id":"a94e9bc8-ed96-4745-90df-ed6e8dac23cc","type":"ColumnDataSource"},"glyph":{"id":"197bc640-9713-4f2e-ba43-54b4846259e1","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8f72e141-3f7f-46c7-9a6c-2b2ced6cf726","type":"Image"},"selection_glyph":null},"id":"800e9cc2-974f-4fbd-8bfa-dcf7c0700851","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[100,100]}]}},"id":"a94e9bc8-ed96-4745-90df-ed6e8dac23cc","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"eff8f5f6-87c8-4acb-b707-726a06e0e353","type":"PanTool"},{"id":"94473f8f-38e5-4cb0-9f5f-549630844f7c","type":"WheelZoomTool"},{"id":"e15944d8-b1ab-4955-94e7-d7b5510ef2e3","type":"BoxZoomTool"},{"id":"4bc70abf-f520-464b-a668-ee62691e410a","type":"SaveTool"},{"id":"17e961ed-079e-4307-8c44-5c20c5bbfac6","type":"ResetTool"},{"id":"c3f61700-33f2-4ae6-8813-8b8703848ee9","type":"HelpTool"}]},"id":"1be31efd-8745-4861-ac15-46a5b58ba8a0","type":"Toolbar"},{"attributes":{"overlay":{"id":"f4d82257-d488-4952-927d-e6c13c9e0d7c","type":"BoxAnnotation"},"plot":{"id":"78e60051-ca6f-485f-8c4a-f7740ef5b719","subtype":"Figure","type":"Plot"}},"id":"e15944d8-b1ab-4955-94e7-d7b5510ef2e3","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"2cd3cec5-7d61-418b-8940-45732e590550","type":"LinearAxis"}],"left":[{"id":"f961f9bb-cf7d-4ea6-a1d6-13080ac0d030","type":"LinearAxis"}],"renderers":[{"id":"2cd3cec5-7d61-418b-8940-45732e590550","type":"LinearAxis"},{"id":"797d8348-eb04-43fa-ac59-1b72e5992b7d","type":"Grid"},{"id":"f961f9bb-cf7d-4ea6-a1d6-13080ac0d030","type":"LinearAxis"},{"id":"7b517624-4ca1-4b7c-95ba-6961c9285be6","type":"Grid"},{"id":"f4d82257-d488-4952-927d-e6c13c9e0d7c","type":"BoxAnnotation"},{"id":"800e9cc2-974f-4fbd-8bfa-dcf7c0700851","type":"GlyphRenderer"}],"title":{"id":"af685ce9-6122-48e4-931d-fd8d536f42b6","type":"Title"},"tool_events":{"id":"32c03841-d2d5-4f3a-8e1f-f96dec2ce71c","type":"ToolEvents"},"toolbar":{"id":"1be31efd-8745-4861-ac15-46a5b58ba8a0","type":"Toolbar"},"x_range":{"id":"9bdf1137-c37c-4e31-9830-16f69a98561e","type":"Range1d"},"x_scale":{"id":"6f687293-506e-427a-ba0f-277bb58f760b","type":"LinearScale"},"y_range":{"id":"e09d23f0-9958-4dfa-80b3-145a061604f8","type":"Range1d"},"y_scale":{"id":"f40db235-9a6f-46cb-b0ef-250e4e5d5662","type":"LinearScale"}},"id":"78e60051-ca6f-485f-8c4a-f7740ef5b719","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"07297847-81d1-444f-88ce-328eff583775","type":"BasicTicker"},{"attributes":{"color_mapper":{"id":"2d0bf875-2479-40fa-b168-d63e9e2d1ac6","type":"LinearColorMapper"},"dh":{"units":"data","value":100},"dw":{"units":"data","value":100},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"8f72e141-3f7f-46c7-9a6c-2b2ced6cf726","type":"Image"},{"attributes":{},"id":"1c289d92-f2d9-488e-b7fb-798dc0a6b6d6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"78e60051-ca6f-485f-8c4a-f7740ef5b719","subtype":"Figure","type":"Plot"}},"id":"4bc70abf-f520-464b-a668-ee62691e410a","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"af685ce9-6122-48e4-931d-fd8d536f42b6","type":"Title"},{"attributes":{"plot":{"id":"78e60051-ca6f-485f-8c4a-f7740ef5b719","subtype":"Figure","type":"Plot"}},"id":"c3f61700-33f2-4ae6-8813-8b8703848ee9","type":"HelpTool"},{"attributes":{},"id":"a40f3a04-f57e-43f3-aa97-a99c623acb46","type":"BasicTicker"},{"attributes":{"callback":null,"end":110,"start":-10},"id":"9bdf1137-c37c-4e31-9830-16f69a98561e","type":"Range1d"},{"attributes":{},"id":"32c03841-d2d5-4f3a-8e1f-f96dec2ce71c","type":"ToolEvents"},{"attributes":{"color_mapper":{"id":"225c0136-29e6-474f-9996-0d2950aa88ee","type ...
