# %%
import numpy as np
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import operator
from analysis_count_0g import read_n, classify_imgs2
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py', '-f', 'true', 'true', 'true', 'true', 'true', 'model_runs/-f/count_log.csv', 'model_runs/-f/countmodel_0.ckpt', 'model_runs/-f/countmodel_', 'true', 'false', 'false', 'true']
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:307: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From /home/mtfang/DRAM/Ct_2l_3t_0g_viz.py:308: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# analysis_count.py

# %%
model_name = "3task_0305"
num_runs = 1
test_trials = 10
iter_list = [5000]#np.arange(0,3500,500)#[3200, 4800, 6400, 9600, 12800]#, 200, 300, 400, 600, 800, 1200]#, 1600, 2400, 3200, 4800, 6400, 9600, 12800, 19200, 25600, 38400, 51200, 76800, 102400]#, 153600, 204800, 307200, 409600, 614400, 819200, 1000000]
            #[0, 400, 800, 1600, 3200, 6400, 12800, 25600]#, 51200, 76800, 102400]#, 153600, 204800, 307200, 409600, 614400, 819200, 1000000, 2000000, 3000000, 4000000]
             #[0, 1000, 4000, 16000, 32000, 64000, 125000, 250000, 500000, 600000]
#iter_list = np.arange(0,11100000,100000)
glimpse_list = np.arange(0,10,1)
max_blobs = 9
min_blobs = 1

num_iters = len(iter_list)
num_glimpses = len(glimpse_list)
blob_list = np.arange(0,10,1)
output_size = max_blobs - min_blobs + 2 # 10
data_directory = "data/" + model_name + "/"
m = 0.5
num_imgs = test_trials*(output_size-1)

blob_point_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
class_all_runs = np.zeros([num_runs, num_iters, num_imgs])
pred_gx_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
tchr_gx_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
pred_gy_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
tchr_gy_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])
size_all_runs = np.zeros([num_runs, num_iters, num_imgs, output_size+1])

# %%
def fill_matrix(path, iteration):
    """Fill the confidence and choice matrices for one run at one iteration."""
    
    data = None
    num_imgs = test_trials*(output_size-1) # batch_size
    imgs_data = classify_imgs2(iteration, True, num_imgs, path=path) # new_imgs = True
        
    blob_point_one_run = np.zeros([num_imgs, output_size+1])
    class_one_run = np.zeros(num_imgs)
    pred_gx_one_run = np.zeros([num_imgs, output_size+1])
    tchr_gx_one_run = np.zeros([num_imgs, output_size+1])
    pred_gy_one_run = np.zeros([num_imgs, output_size+1])
    tchr_gy_one_run = np.zeros([num_imgs, output_size+1])
    size_one_run = np.zeros([num_imgs, output_size+1])
    
    for idx, data in enumerate(imgs_data):
        for g in range(num_glimpses):
            blob_point_one_run[idx][g] = int(data["blob_point"][g])
            pred_gx_one_run[idx][g] = data["xs"][g][0]
            tchr_gx_one_run[idx][g] = data["xs"][g][1]
            pred_gy_one_run[idx][g] = data["ys"][g][0]
            tchr_gy_one_run[idx][g] = data["ys"][g][1]
            size_one_run[idx][g] = int(data["size"][g])
        class_one_run[idx] = data["class"]+1      
    
    return blob_point_one_run, class_one_run, pred_gx_one_run, tchr_gx_one_run, pred_gy_one_run, tchr_gy_one_run, size_one_run

# %%
for run in range(num_runs):
    path = 'model_runs/' + model_name + '_run_' + str(run + 1) 
#     path = 'model_runs/DRAM_test_square'
    for i, iteration in enumerate(iter_list):
        blob_point_all_runs[run, i], class_all_runs[run, i], pred_gx_all_runs[run, i], tchr_gx_all_runs[run, i], pred_gy_all_runs[run, i], tchr_gy_all_runs[run, i], size_all_runs[run, i] = fill_matrix(path, iteration)
# Out:
# INFO:tensorflow:Restoring parameters from model_runs/3task_0305_run_1/countmodel_5000.ckpt

# %%
class_all_runs[0,0,2]
tchr_gx_all_runs[0,0,0][0:10]
#size_all_runs[0,0,0]
blob_point_all_runs[0,0,0]
tchr_gx_all_runs[0,0,0][0:10]
# Out:
# array([ 10.5,  19.5,  27.5,  36.5,  44.5,  53.5,  61.5,  61.5,  61.5,  61.5])

# %%
tchr_gx_all_runs[0,0,0][0:10]
# Out:
# array([ 11.5,  20.5,  29.5,  38.5,  46.5,  55.5,  55.5,  55.5,  55.5,  55.5])

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

it=0
for t in range(num_imgs):
    if class_all_runs[0,it,t]==9:
        img=t
        break
        
# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size

# generate blobs
width = 5
height = 5

# top left corner coordinate
cX = tchr_gx_all_runs[0,it,img][0:int(class_all_runs[0,it,img])]-2.5
cY = tchr_gy_all_runs[0,it,img][0:int(class_all_runs[0,it,img])]-2.5

k = len(cX)

# input_img
input_img = np.ones(dims[0]*dims[1])
for i in range(k):
    for j in range(int(cY[i]), int(cY[i]+height)):
        for k in range(int(cX[i]), int(cX[i]+width)):
            input_img[j*dims[0]+k] = 255
            
input_img = np.reshape(input_img,(dims[0],dims[1]))

# %%
tchr_gx_all_runs[0,0,0]

# %%
print("blob_point:", blob_point_all_runs[0,it,img][0:int(class_all_runs[0,it,img]+1)])
for i in range(int(class_all_runs[0,it,img]+1)):
               # attention window
               gx = tchr_gx_all_runs[0,it,img,i]
               gy = tchr_gy_all_runs[0,it,img,i]
               pred_gx = pred_gx_all_runs[0,it,img,i]
               pred_gy = pred_gy_all_runs[0,it,img,i]
               print("gx:", gx)
               print("gy:", gy)
               xx=np.reshape([gx-3.5,gx,gx+3.5], (-1,1))
               yy=np.reshape([gy-3.5,gy,gy+3.5], (-1,1))
               mu_x_1_list = np.reshape([xx]*3,[-1])
               mu_y_1_list = np.reshape(np.transpose([yy]*3),[-1])

               input_img = np.reshape(input_img,(dims[0],dims[1]))

               cross_source = ColumnDataSource(
                   data=dict(
                       cross_x=[gx],
                       cross_y=[gy],
                       desc=['Att_window Center'],
                   )
               )

               dot_source_1 = ColumnDataSource(
                   data=dict(
                       mu_x_1=mu_x_1_list,
                       mu_y_1=mu_y_1_list,
                   )
               )

               source = ColumnDataSource(
                   data=dict(
                       x=[pred_gx],
                       y=[pred_gy],
                   )
               )

               p = figure(title="Input Image (gx=%-d, gy=%-d)" %(gx,gy), x_range=(0, 100), y_range=(0, 100))
               iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
               p.circle('mu_x_1', 'mu_y_1', size=5, source=dot_source_1, color="orange")
               p.cross('cross_x', 'cross_y', size=10, source=cross_source, color="blue")
               p.circle('x', 'y', size=5, source=source, color="red")

               output_notebook()

               show(p)

# %%
gx
# Out:
# 46.5

# %% [markdown]
# # Generate Image

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size
num_filter = N*N+N*N
# delta, sigma2
delta_1=max(dims[0],dims[1])*1.5/(N-1)
sigma2_1=delta_1*delta_1/4 # sigma=delta/2
delta_2=max(dims[0],dims[1])/3/(N-1)
sigma2_2=delta_2*delta_2/4 # sigma=delta/2

num_blobs = 5
img = np.ones(dims[0]*dims[1])
img_width = dims[0]
img_height = dims[1]
num_count = 0
glimpse_count = 0
# top left corner coordinate
cX_prev = 0
cY_prev = 0
# generate blobs
while num_count < num_blobs:
    width = 5
    height = 5
    cX_ = random.randint(8, 9)
    cY_ = 3
    if num_count == 0:
        cX = cX_
        cY = random.randint(img_height/2 - cY_, img_height/2 + cY_ - height)
        cX0 = cX
        cY0 = cY
    else:
        cX = cX_prev + cX_
        cY = random.randint(img_height/2 - cY_, img_height/2 + cY_ - height)
    cX_prev = cX
    cY_prev = cY
        
    for p in range(cY, cY+height):
        for q in range(cX, cX+width):
            img[p*img_width+q] = 255
                
    num_count += 1
    glimpse_count += 1

# attention window
gx = cX0+2.5#dims[0]/2
gy = cY0+2.5#dims[1]/2

grid_i = np.arange(N)
mu_x_1 = np.reshape(gx + (grid_i - N / 2 + 0.5) * delta_1, (-1,1))
mu_y_1 = np.reshape(gy + (grid_i - N / 2 + 0.5) * delta_1, (-1,1)) 
mu_x_2 = np.reshape(gx + (grid_i - N / 2 + 0.5) * delta_2, (-1,1))
mu_y_2 = np.reshape(gy + (grid_i - N / 2 + 0.5) * delta_2, (-1,1))
a = np.reshape(np.arange(dims[0]), (1, -1)) 
b = np.reshape(np.arange(dims[1]), (1, -1)) 

mu_x_1_list = np.reshape([mu_x_1]*N,[-1]) 
mu_y_1_list = np.reshape(np.transpose([mu_y_1]*N),[-1]) 
mu_x_2_list = np.reshape([mu_x_2]*N,[-1]) 
mu_y_2_list = np.reshape(np.transpose([mu_y_2]*N),[-1])

Fx_1 = np.exp(-np.square(a - mu_x_1) / (2*sigma2_1)) 
Fy_1 = np.exp(-np.square(b - mu_y_1) / (2*sigma2_1)) 
Fx_2 = np.exp(-np.square(a - mu_x_2) / (2*sigma2_2))
Fy_2 = np.exp(-np.square(b - mu_y_2) / (2*sigma2_2))

# normalize, sum over A and B dims
Fx_1=Fx_1/np.reshape(np.sum(Fx_1,axis=1),(-1,1))
Fy_1=Fy_1/np.reshape(np.sum(Fy_1,axis=1),(-1,1))
Fx_2=Fx_2/np.reshape(np.sum(Fx_2,axis=1),(-1,1))
Fy_2=Fy_2/np.reshape(np.sum(Fy_2,axis=1),(-1,1))

# %%
input_img = np.reshape(img,(dims[0],dims[1]))
#filter_img
Fxt_1=np.transpose(Fx_1)
np.shape(Fxt_1)
filter_img_1=np.matmul(Fy_1, np.matmul(input_img, Fxt_1))
filter_img_1=np.log(np.reshape(filter_img_1,(N,N)))

Fxt_2=np.transpose(Fx_2)
np.shape(Fxt_2)
filter_img_2=np.matmul(Fy_2, np.matmul(input_img, Fxt_2))
filter_img_2=np.log(np.reshape(filter_img_2,(N,N)))

hover = HoverTool(
        tooltips="""
        <div>
            <div>
                <span style="font-size: 15px; font-weight: bold;">@desc</span>
            </div>
            <div>
                <span style="font-size: 12px;">Location</span>
                <span style="font-size: 12px; color: #320;">($x, $y)</span>
            </div>
        </div>
        """
    )


source = ColumnDataSource(
        data=dict(
            x=[gx],
            y=[gy],
            desc=['Att_window Center'],
        )
)

dot_source_1 = ColumnDataSource(
        data=dict(
            mu_x_1=mu_x_1_list,
            mu_y_1=mu_y_1_list,
            #desc=['Att_window Center'],
        )
)

dot_source_2 = ColumnDataSource(
        data=dict(
            mu_x_2=mu_x_2_list,
            mu_y_2=mu_y_2_list,
            #desc=['Att_window Center'],
        )
)

p = figure(title="Input Image (gx=%-d, gy=%-d)" %(gx,gy), x_range=(0, 20), y_range=(40, 60), tools=[hover])
iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
p.circle('mu_x_1', 'mu_y_1', size=5, source=dot_source_1, color="orange")
p.circle('mu_x_2', 'mu_y_2', size=5, source=dot_source_2, color="blue")
p.circle('x', 'y', size=3, source=source, color="red")



filter_source = ColumnDataSource(
        data=dict(
            x=[N/2],
            y=[N/2],
            desc=['Filterbank Center'],
        )
)


p_filter_1 = figure(title="Outer Layer Filter Image", x_range=(0, 15), y_range=(0, 15))
iii = p_filter_1.image(image=[filter_img_1], x=0, y=0, dw=15, dh=15, palette="Greys256")
p_filter_1.circle('x', 'y', size=10, source=filter_source, color="red")

p_filter_2 = figure(title="Inner Layer Filter Image", x_range=(0, 15), y_range=(0, 15))
iii = p_filter_2.image(image=[filter_img_2], x=0, y=0, dw=15, dh=15, palette="Greys256")
p_filter_2.circle('x', 'y', size=10, source=filter_source, color="red")

output_notebook()

show(p)
pp = gridplot([[p_filter_1,p_filter_2]], toolbar_location="right")
show(pp)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ef23fe23-b1cb-45d0-b0f2-eb9c356fe03f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1a206ac1-60f9-4b8d-9449-1c994273ec47"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1a206ac1-60f9-4b8d-9449-1c994273ec47");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a206ac1-60f9-4b8d-9449-1c994273ec47");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a206ac1-60f9-4b8d-9449-1c994273ec47' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6f26ed07-e346-45d7-b237-991cddf2bad1":{"roots":{"references":[{"attributes":{"callback":null,"end":20},"id":"ecb04db3-c07d-4955-8a73-09fe17a4d686","type":"Range1d"},{"attributes":{},"id":"f09e82a9-12d5-49f7-ba76-cd3617bdf2b8","type":"LinearScale"},{"attributes":{"data_source":{"id":"f9a7a5b7-cce1-4090-900b-33f598545dad","type":"ColumnDataSource"},"glyph":{"id":"3e67cb14-438e-432d-aeee-e5e2ed26d8c2","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2cf6a483-e0a5-4d82-9523-5aa4091b51a9","type":"Image"},"selection_glyph":null},"id":"a1acb84f-b90f-4afc-8e2d-84b074c934b9","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Input Image (gx=10, gy=49)"},"id":"3a28e27f-993f-458d-8808-bb7e20c05b1f","type":"Title"},{"attributes":{"callback":null,"column_names":["mu_y_1","mu_x_1"],"data":{"mu_x_1":{"__ndarray__":"...","dtype":"float64","shape":[225]},"mu_y_1":{"__ndarray__":"...","dtype":"float64","shape":[225]}}},"id":"d68263a7-0bb9-47b9-a0ac-b40a84fd0fca","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"mu_x_2"},"y":{"field":"mu_y_2"}},"id":"762d3ad0-7d06-4ad4-8705-20e406e1f703","type":"Circle"},{"attributes":{"data_source":{"id":"7f7c10c0-0d12-475a-ba9c-840aea085c85","type":"ColumnDataSource"},"glyph":{"id":"870c3808-4f13-4c5a-8657-a55c6261fd09","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"762d3ad0-7d06-4ad4-8705-20e406e1f703","type":"Circle"},"selection_glyph":null},"id":"e6f82f83-ea44-40c1-9871-6d4f663d4a24","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[100,100]}]}},"id":"f9a7a5b7-cce1-4090-900b-33f598545dad","type":"ColumnDataSource"},{"attributes":{"palette":["#000000","#010101","#020202","#030303","#040404","#050505","#060606","#070707","#080808","#090909","#0a0a0a","#0b0b0b","#0c0c0c","#0d0d0d","#0e0e0e","#0f0f0f","#101010","#111111","#121212","#131313","#141414","#151515","#161616","#171717","#181818","#191919","#1a1a1a","#1b1b1b","#1c1c1c","#1d1d1d","#1e1e1e","#1f1f1f","#202020","#212121","#222222","#232323","#242424","#252525","#262626","#272727","#282828","#292929","#2a2a2a","#2b2b2b","#2c2c2c","#2d2d2d","#2e2e2e","#2f2f2f","#303030","#313131","#323232","#333333","#343434","#353535","#363636","#373737","#383838","#393939","#3a3a3a","#3b3b3b","#3c3c3c","#3d3d3d","#3e3e3e","#3f3f3f","#404040","#414141","#424242","#434343","#444444","#454545","#464646","#474747","#484848","#494949","#4a4a4a","#4b4b4b","#4c4c4c","#4d4d4d","#4e4e4e","#4f4f4f","#505050","#515151","#525252","#535353","#545454","#555555","#565656","#575757","#585858","#595959","#5a5a5a","#5b5b5b","#5c5c5c","#5d5d5d","#5e5e5e","#5f5f5f","#606060","#616161","#626262","#636363","#646464","#656565","#666666","#676767","#686868","#696969","#6a6a6a","#6b6b6b","#6c6c6c","#6d6d6d","#6e6e6e","#6f6f6f","#707070","#717171","#727272","#737373","#747474","#757575","#767676","#777777","#787878","#797979","#7a7a7a","#7b7b7b","#7c7c7c","#7d7d7d","#7e7e7e","#7f7f7f","#808080","#818181","#828282","#838383","#848484","#858585","#868686","#878787","#888888","#898989","#8a8a8a","#8b8b8b","#8c8c8c","#8d8d8d","#8e8e8e","#8f8f8f","#909090","#919191","#929292","#939393","#949494","#959595","#969696","#979797","#989898","#999999","#9a9a9a","#9b9b9b","#9c9c9c","#9d9d9d","#9e9e9e","#9f9f9f","#a0a0a0","#a1a1a1","#a2a2a2","#a3a3a3","#a4a4a4","#a5a5a5","#a6a6a6","#a7a7a7","#a8a8a8","#a9a9a9","#aaaaaa","#ababab","#acacac","#adadad","#aeaeae","#afafaf","#b0b0b0","#b1b1b1","#b2b2b2","#b3b3b3","#b4b4b4","#b5b5b5","#b6b6b6","#b7b7b7","#b8b8b8","#b9b9b9","#bababa","#bbbbbb","#bcbcbc","#bdbdbd","#bebebe","#bfbfbf","#c0c0c0","#c1c1c1","#c2c2c2","#c3c3c3","#c4c4c4","#c5c5c5","#c6c6c6","#c7c7c7","#c8c8c8","#c9c9c9","#cacaca","#cbcbcb","#cccccc" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b56a5b7e-70f1-4636-8856-444766da6a4d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b56a5b7e-70f1-4636-8856-444766da6a4d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b56a5b7e-70f1-4636-8856-444766da6a4d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b56a5b7e-70f1-4636-8856-444766da6a4d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fa3e4f22-0965-493b-acde-b68176d74ed3":{"roots":{"references":[{"attributes":{"plot":{"id":"86efd17f-2e99-487f-824a-0ba53f33a852","subtype":"Figure","type":"Plot"}},"id":"ea9b2352-f61e-4029-82cb-938d4cffae0b","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"aefe0595-371e-4d2f-a0f4-0c2cd63f32ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"2654ed10-0e63-4367-98d1-7f0be836aabb","type":"BasicTicker"}},"id":"efcba140-043b-4ba8-b9d7-b8c9c9b940aa","type":"Grid"},{"attributes":{"data_source":{"id":"0fef428c-8373-4280-96b5-f85aff9103f2","type":"ColumnDataSource"},"glyph":{"id":"a99b3905-6114-4c5d-8e37-253b94d258ea","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8cabb1a0-d697-4cc2-a62c-23db7993f05e","type":"Circle"},"selection_glyph":null},"id":"4e56fd73-897c-4879-afe9-21efc388bcd2","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"366d6c74-e4a2-4389-8fbb-cb47569cfcc5","type":"Column"},{"id":"c3ebd5bd-63a7-4d1b-88e7-b409390acd78","type":"ToolbarBox"}]},"id":"6cd65e8e-8276-47c5-8ebe-bc766fb59e10","type":"Row"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c90cfa3e-b3ac-4a90-8dcd-3762fa23140c","type":"PanTool"},{"id":"cb4db9a8-6540-4000-abdb-5c3eee83d610","type":"WheelZoomTool"},{"id":"67fdcae3-bd10-48d6-95f1-ec757eba8704","type":"BoxZoomTool"},{"id":"d4845c18-e69a-4efe-9dc9-0d60e183fcca","type":"SaveTool"},{"id":"fab5676a-b74f-41fe-9fdd-aef73316cae1","type":"ResetTool"},{"id":"2508c802-e5ba-479f-978b-6cb6b8319de3","type":"HelpTool"}]},"id":"a9641b72-a314-4c42-9e99-31bf719b53fc","type":"Toolbar"},{"attributes":{"callback":null,"end":15},"id":"538380f0-4a5e-4bf8-84f8-45bdada70976","type":"Range1d"},{"attributes":{"color_mapper":{"id":"750423e1-f058-4635-a822-c594a33f7caf","type":"LinearColorMapper"},"dh":{"units":"data","value":15},"dw":{"units":"data","value":15},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"19f50c2b-24c3-47b3-883c-65c6e29b92d1","type":"Image"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7cd535d3-5e8d-4249-a549-b4ac6504dead","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"936eade7-4ccc-4c66-be3c-85e5e4a4ec38","type":"LinearAxis"}],"left":[{"id":"d5ba3699-b33a-4f6e-8fdc-e58a272961ea","type":"LinearAxis"}],"renderers":[{"id":"936eade7-4ccc-4c66-be3c-85e5e4a4ec38","type":"LinearAxis"},{"id":"cbcaf06a-8c22-42af-9e17-08a1eb5b363f","type":"Grid"},{"id":"d5ba3699-b33a-4f6e-8fdc-e58a272961ea","type":"LinearAxis"},{"id":"efcba140-043b-4ba8-b9d7-b8c9c9b940aa","type":"Grid"},{"id":"7cd535d3-5e8d-4249-a549-b4ac6504dead","type":"BoxAnnotation"},{"id":"431ddb13-95e2-4534-bfe9-2338222feffb","type":"GlyphRenderer"},{"id":"8c68f433-6668-4556-a4ce-14e2f80f705b","type":"GlyphRenderer"}],"title":{"id":"7fc5dc98-9304-4bf2-b37d-3d82f1fe81ca","type":"Title"},"tool_events":{"id":"4c88c8db-5015-4a4d-adbd-2efaa6c26102","type":"ToolEvents"},"toolbar":{"id":"a9641b72-a314-4c42-9e99-31bf719b53fc","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"01a6272f-6efc-4153-8ef2-e3b9fa53bf14","type":"Range1d"},"x_scale":{"id":"d22c5e6c-983a-4e58-bf1c-81adf66aa364","type":"LinearScale"},"y_range":{"id":"79c67200-0178-4909-905e-40a88eaca91f","type":"Range1d"},"y_scale":{"id":"0d1fe402-5394-4763-86d3-2e6b23b6d5df","type":"LinearScale"}},"id":"aefe0595-371e-4d2f-a0f4-0c2cd63f32ec","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"86efd17f-2e99-487f-824a-0ba53f33a852","subtype":"Figure","type":"Plot"}},"id":"6d9b5104-c3df-43e7-8cb7-f83d2000eaf1","type":"HelpTool"},{"attributes":{},"id":"f00654cc-0812-4f00-8cc9-e47ed88a89f1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id": ...

# %%
import sys
import numpy as np
import random

from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
from bokeh.io import output_notebook

# parameters
N = 15  # N x N filterbank for each layer
dims = [100,100] # input_img size
num_blobs = 5
img = np.ones(dims[0]*dims[1])
img_width = dims[0]
img_height = dims[1]
num_count = 0
glimpse_count = 0
# generate blobs
cX = 20
cY = 20
for p in range(cX, cX+5):
    for q in range(cY, cY+5):
        img[p*img_width+q] = 255
        
input_img = np.reshape(img,(dims[0],dims[1]))

source = ColumnDataSource(
        data=dict(
            x=[cX],
            y=[cY],
            desc=['Filterbank Center'],
        )
)
p = figure(x_range=(0, 100), y_range=(0, 100))
iii = p.image(image=[input_img], x=0, y=0, dw=100, dh=100, palette="Greys256")
p.circle('x', 'y', size=5, source=source, color="red")
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fbee898c-4e23-425c-b1de-6a25352f3608">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c00808f1-7a7a-43e0-aec3-7ce76cb9bc9b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c00808f1-7a7a-43e0-aec3-7ce76cb9bc9b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c00808f1-7a7a-43e0-aec3-7ce76cb9bc9b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c00808f1-7a7a-43e0-aec3-7ce76cb9bc9b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ed9dd5f0-cea8-4933-8021-8bf0022b7ace":{"roots":{"references":[{"attributes":{"color_mapper":{"id":"042cba31-9d82-4fd7-9830-a936012d2263","type":"LinearColorMapper"},"dh":{"units":"data","value":100},"dw":{"units":"data","value":100},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"c09117f9-3136-4b6f-96c3-aaadfc1501e0","type":"Image"},{"attributes":{"data_source":{"id":"b7a22a97-edf9-40db-9173-227d79a4883c","type":"ColumnDataSource"},"glyph":{"id":"5472dc40-3c67-42ab-bfdf-bcabdf60f2e1","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a9a7e8ab-5951-424d-ab2e-e9970205ea62","type":"Circle"},"selection_glyph":null},"id":"ad796372-15ab-4d92-a845-497116fcfbed","type":"GlyphRenderer"},{"attributes":{},"id":"2eb9becf-f6bc-45b2-b50e-fefbd2086efd","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[100,100]}]}},"id":"197d1544-2fef-4f23-8526-b6cb5416c6c5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","desc"],"data":{"desc":["Filterbank Center"],"x":[20],"y":[20]}},"id":"b7a22a97-edf9-40db-9173-227d79a4883c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"197d1544-2fef-4f23-8526-b6cb5416c6c5","type":"ColumnDataSource"},"glyph":{"id":"b7794df7-fa4f-452e-bb94-1e6f39fdfe26","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c09117f9-3136-4b6f-96c3-aaadfc1501e0","type":"Image"},"selection_glyph":null},"id":"837d9897-d027-41eb-a5a2-bb66138db6d6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"cb9f67d6-541d-4274-856e-127e504c02f1","subtype":"Figure","type":"Plot"}},"id":"0c0abf9a-dbd3-4d6d-a97d-7e36bc2994ba","type":"SaveTool"},{"attributes":{"plot":{"id":"cb9f67d6-541d-4274-856e-127e504c02f1","subtype":"Figure","type":"Plot"}},"id":"c2050739-e5ba-42d6-acb3-de6753029061","type":"PanTool"},{"attributes":{},"id":"54120da1-12bb-4f7d-a043-fb22944d37fe","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c2050739-e5ba-42d6-acb3-de6753029061","type":"PanTool"},{"id":"cb2ef36f-546f-4607-84ab-f8840dab6ff3","type":"WheelZoomTool"},{"id":"aa0ee7ef-0533-4b17-b7a9-3da67d02fab2","type":"BoxZoomTool"},{"id":"0c0abf9a-dbd3-4d6d-a97d-7e36bc2994ba","type":"SaveTool"},{"id":"c53cfd90-e431-48ba-a2f6-65485d90ee52","type":"ResetTool"},{"id":"44c4a0e4-05c5-446b-880d-2ab968155201","type":"HelpTool"}]},"id":"4c586c29-7138-48f6-8303-1f4619a7b06c","type":"Toolbar"},{"attributes":{"plot":{"id":"cb9f67d6-541d-4274-856e-127e504c02f1","subtype":"Figure","type":"Plot"}},"id":"cb2ef36f-546f-4607-84ab-f8840dab6ff3","type":"WheelZoomTool"},{"attributes":{"palette":["#000000","#010101","#020202","#030303","#040404","#050505","#060606","#070707","#080808","#090909","#0a0a0a","#0b0b0b","#0c0c0c","#0d0d0d","#0e0e0e","#0f0f0f","#101010","#111111","#121212","#131313","#141414","#151515","#161616","#171717","#181818","#191919","#1a1a1a","#1b1b1b","#1c1c1c","#1d1d1d","#1e1e1e","#1f1f1f","#202020","#212121","#222222","#232323","#242424","#252525","#262626","#272727","#282828","#292929","#2a2a2a","#2b2b2b","#2c2c2c","#2d2d2d","#2e2e2e","#2f2f2f","#303030","#313131","#323232","#333333","#343434","#353535","#363636","#373737","#383838","#393939","#3a3a3a","#3b3b3b","#3c3c3c","#3d3d3d","#3e3e3e","#3f3f3f","#404040","#414141","#424242","#434343","#444444","#454545","#464646","#474747","#484848","#494949","#4a4a4a","#4b4b4b","#4c4c4c","#4d4d4d","#4e4e4e","#4f4f4f","#505050","#515151","#525252","#535353","#545454","#555555","#565656","#575757","#585858","#595959","#5a5a5a","#5b5b5b","#5c5c5c","#5d5d5d","#5e5e5e","#5f5f5f","#606060","#616161","#626262","#636363","#646464","#656565","#666666","#676767","#686868","#696969","#6a6a6a","#6b6b6b","#6c6c6c","#6d6d6d","#6e6e6e","#6f6f6f","#707070","#717171","#727272","#737373","#747474","#757575","#767676","#777777 ...

# %%
gx
# Out:
# 10.5

# %%
gy
# Out:
# 49.5

# %%
mu_x_2
# Out:
# array([[ -6.16666667],
#        [ -3.78571429],
#        [ -1.4047619 ],
#        [  0.97619048],
#        [  3.35714286],
#        [  5.73809524],
#        [  8.11904762],
#        [ 10.5       ],
#        [ 12.88095238],
#        [ 15.26190476],
#        [ 17.64285714],
#        [ 20.02380952],
#        [ 22.4047619 ],
#        [ 24.78571429],
#        [ 27.16666667]])

# %%
cX0
# Out:
# 8

# %%
cY0
# Out:
# 47
