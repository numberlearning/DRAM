# %%
from viz_twolayer import *
# Out:
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='0c2ffd3f-cfcf-4e6c-87f6-8bde1ab06ab1', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='0c76c65e-dad9-41af-985a-c568e010bf80', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='507d18c2-2a66-4fa7-97ce-654cee1ddfa3', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='6809c220-3c8e-47cf-bcad-e718f3bb85e4', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='964aed9d-721c-4f4c-bf9b-c3002513e45d', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='97886762-dcfb-49af-93b5-be20edb5ebdf', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='cf152b64-ab55-4c9f-90e8-c1d98e0d2698', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='dc0f3c32-3efe-4d94-b7ae-99b785a7255b', ...)
# ...
